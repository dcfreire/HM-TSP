# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
opt = {
    "st70": 675,
    "att48": 10628,
    "kroB100": 22141,
    "pr107": 44303,
    "kroD100": 21294,
    "kroA150": 26524,
    "lin105": 14379,
    "kroB200": 29437,
    "kroB150": 26130,
    "pr124": 59030,
    "kroC100": 20749,
    "rat195": 2323,
    "kroA200": 29368,
    "pr76": 108159,
    "pr152": 73682,
    "pr144": 58537,
    "berlin52": 7542,
    "rat99": 1211,
    "kroA100": 21282,
    "kroE100": 22068,
    "pr136": 96772,
}

out_greedy = {    
    "st70": 830,
    "att48": 12861,
    "kroB100": 29158,
    "pr107": 46680,
    "kroD100": 26947,
    "kroA150": 33633,
    "lin105": 20356,
    "kroB200": 36980,
    "kroB150": 34499,
    "pr124": 69297,
    "kroC100": 26227,
    "rat195": 2752,
    "kroA200": 35859,
    "pr76": 153462,
    "pr152": 85699,
    "pr144": 61652,
    "berlin52": 8980,
    "rat99": 1554,
    "kroA100": 27807,
    "kroE100": 27460,
    "pr136": 120769,
    }
out_vsn = {
    "st70.tsp": 721.0,
    "att48.tsp": 10959.0,
    "kroB100.tsp": 22700.0,
    "pr107.tsp": 44577.0,
    "kroD100.tsp": 22695.0,
    "kroA150.tsp": 28551.0,
    "lin105.tsp": 15851.0,
    "kroB200.tsp": 32690.0,
    "kroB150.tsp": 28047.0,
    "pr124.tsp": 62593.0,
    "kroC100.tsp": 22510.0,
    "rat195.tsp": 2447.0,
    "kroA200.tsp": 29932.0,
    "pr76.tsp": 115994.0,
    "pr152.tsp": 77774.0,
    "pr144.tsp": 61228.0,
    "berlin52.tsp": 8009.0,
    "rat99.tsp": 1255.0,
    "kroA100.tsp": 23161.0,
    "kroE100.tsp": 24488.0,
    "pr136.tsp": 105082.0,
}

out_tabu = {
    "st70.tsp": 687.0,
    "att48.tsp": 10772.0,
    "kroB100.tsp": 22258.0,
    "pr107.tsp": 44499.0,
    "kroD100.tsp": 21663.0,
    "kroA150.tsp": 28211.0,
    "lin105.tsp": 14682.0,
    "kroB200.tsp": 31942.0,
    "kroB150.tsp": 27248.0,
    "pr124.tsp": 60134.0,
    "kroC100.tsp": 22752.0,
    "rat195.tsp": 2347.0,
    "kroA200.tsp": 29578.0,
    "pr76.tsp": 108304.0,
    "pr152.tsp": 75832.0,
    "pr144.tsp": 58590.0,
    "berlin52.tsp": 7902.0,
    "rat99.tsp": 1236.0,
    "kroA100.tsp": 21852.0,
    "kroE100.tsp": 22856.0,
    "pr136.tsp": 103307.0,

}

# %%
x = np.arange(len(opt))
w = 0.35
fig, ax = plt.subplots(figsize=(15,6))
rects1 = ax.bar(x-w/2, opt.values(), w/2, label="Optimal")
rects2 = ax.bar(x, out_greedy.values(), w/2, label="Greedy")
rects3 = ax.bar(x+w/2, out_vsn.values(), w/2, label="VND")
rects3 = ax.bar(x+2*w/2, out_tabu.values(), w/2, label="Tabu")



ax.set_ylabel("Cost")
ax.set_xlabel("Test File")
ax.set_xticks(x, opt.keys())
ax.legend()
percentages = np.array(list(out_tabu.values()))/np.array(list(opt.values())) - 1
percentages = [f"+{r*100:.2f}%" for r in percentages]
ax.bar_label(rects3, percentages, padding=4)
fig.tight_layout()
